# %%
## Major Crypto currency's data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/final.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Unnamed: 0  Name Symbol        Date       High        Low       Open  \
# 0           0  Aave   AAVE  2020-10-05  55.112358  49.787900  52.675035
# 1           1  Aave   AAVE  2020-10-06  53.402270  40.734578  53.291969
# 2           2  Aave   AAVE  2020-10-07  42.408314  35.970690  42.399947
# 3           3  Aave   AAVE  2020-10-08  44.902511  36.696057  39.885262
# 4           4  Aave   AAVE  2020-10-09  47.569533  43.291776  43.764463
#
#        Close        Volume     Marketcap
# 0  53.219243  0.000000e+00  8.912813e+07
# 1  42.401599  5.830915e+05  7.101144e+07
# 2  40.083976  6.828342e+05  6.713004e+07
# 3  43.764463  1.658817e+06  2.202651e+08
# 4  46.817744  8.155377e+05  2.356322e+08

# %%
df.tail()
# Out:
#        Unnamed: 0 Name Symbol        Date      High       Low      Open  \
# 37077       37077  XRP    XRP  2021-07-02  0.667287  0.634726  0.659890
# 37078       37078  XRP    XRP  2021-07-03  0.683677  0.644653  0.655639
# 37079       37079  XRP    XRP  2021-07-04  0.707783  0.665802  0.673218
# 37080       37080  XRP    XRP  2021-07-05  0.695653  0.648492  0.695653
# 37081       37081  XRP    XRP  2021-07-06  0.679923  0.652676  0.653055
#
#           Close        Volume     Marketcap
# 37077  0.656763  2.061607e+09  3.030759e+10
# 37078  0.672888  1.872820e+09  3.105172e+10
# 37079  0.694945  1.885242e+09  3.206960e+10
# 37080  0.654300  2.076373e+09  3.019395e+10
# 37081  0.665402  1.938959e+09  3.072284e+10

# %%
df.shape
# Out:
# (37082, 10)

# %%
df.describe()
# Out:
#          Unnamed: 0          High           Low          Open         Close  \
# count  37082.000000  37082.000000  37082.000000  37082.000000  37082.000000
# mean   18540.500000   1016.058015    952.987707    985.323755    987.120511
# std    10704.795678   5249.503670   4907.932082   5088.101367   5093.703878
# min        0.000000      0.000089      0.000079      0.000086      0.000086
# 25%     9270.250000      0.075664      0.069536      0.072456      0.072648
# 50%    18540.500000      1.008733      0.999850      1.001157      1.001138
# 75%    27810.750000     31.916399     28.996246     30.459673     30.512205
# max    37081.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  3.708200e+04  3.708200e+04
# mean   3.022542e+09  1.542943e+10
# std    1.190963e+10  7.059128e+10
# min    0.000000e+00  0.000000e+00
# 25%    4.937190e+06  2.395955e+08
# 50%    8.512805e+07  1.405335e+09
# 75%    9.388489e+08  5.159305e+09
# max    3.509679e+11  1.186364e+12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37082 entries, 0 to 37081
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  37082 non-null  int64
#  1   Name        37082 non-null  object
#  2   Symbol      37082 non-null  object
#  3   Date        37082 non-null  object
#  4   High        37082 non-null  float64
#  5   Low         37082 non-null  float64
#  6   Open        37082 non-null  float64
#  7   Close       37082 non-null  float64
#  8   Volume      37082 non-null  float64
#  9   Marketcap   37082 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.8+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Symbol        0
# Date          0
# High          0
# Low           0
# Open          0
# Close         0
# Volume        0
# Marketcap     0
# dtype: int64

# %%
import pandas_datareader.data as web
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime, timedelta
from matplotlib.ticker import ScalarFormatter

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Name Symbol        Date       High        Low       Open      Close  \
# 0  Aave   AAVE  2020-10-05  55.112358  49.787900  52.675035  53.219243
# 1  Aave   AAVE  2020-10-06  53.402270  40.734578  53.291969  42.401599
# 2  Aave   AAVE  2020-10-07  42.408314  35.970690  42.399947  40.083976
# 3  Aave   AAVE  2020-10-08  44.902511  36.696057  39.885262  43.764463
# 4  Aave   AAVE  2020-10-09  47.569533  43.291776  43.764463  46.817744
#
#          Volume     Marketcap
# 0  0.000000e+00  8.912813e+07
# 1  5.830915e+05  7.101144e+07
# 2  6.828342e+05  6.713004e+07
# 3  1.658817e+06  2.202651e+08
# 4  8.155377e+05  2.356322e+08

# %%
df['Volume']=df['Volume'].astype(float)
df['Volume'] = df['Volume'].apply(lambda x: '{:.2f}'.format(x))
df['Marketcap']=df['Marketcap'].astype(float)
df['Marketcap'] = df['Marketcap'].apply(lambda x: '{:.2f}'.format(x))

# %%
df.head()
# Out:
#    Name Symbol        Date       High        Low       Open      Close  \
# 0  Aave   AAVE  2020-10-05  55.112358  49.787900  52.675035  53.219243
# 1  Aave   AAVE  2020-10-06  53.402270  40.734578  53.291969  42.401599
# 2  Aave   AAVE  2020-10-07  42.408314  35.970690  42.399947  40.083976
# 3  Aave   AAVE  2020-10-08  44.902511  36.696057  39.885262  43.764463
# 4  Aave   AAVE  2020-10-09  47.569533  43.291776  43.764463  46.817744
#
#        Volume     Marketcap
# 0        0.00   89128128.86
# 1   583091.46   71011441.25
# 2   682834.19   67130036.90
# 3  1658816.92  220265142.11
# 4   815537.66  235632208.16

# %%
df.tail()
# Out:
#       Name Symbol        Date      High       Low      Open     Close  \
# 37077  XRP    XRP  2021-07-02  0.667287  0.634726  0.659890  0.656763
# 37078  XRP    XRP  2021-07-03  0.683677  0.644653  0.655639  0.672888
# 37079  XRP    XRP  2021-07-04  0.707783  0.665802  0.673218  0.694945
# 37080  XRP    XRP  2021-07-05  0.695653  0.648492  0.695653  0.654300
# 37081  XRP    XRP  2021-07-06  0.679923  0.652676  0.653055  0.665402
#
#               Volume       Marketcap
# 37077  2061607207.81  30307589485.09
# 37078  1872819597.06  31051722073.03
# 37079  1885241526.85  32069596319.40
# 37080  2076373187.71  30193951998.35
# 37081  1938959238.79  30722840710.51

# %%
df.to_csv('final_dataset.csv', index=False)

# %%
from google.colab import files
files.download('final_dataset.csv')
